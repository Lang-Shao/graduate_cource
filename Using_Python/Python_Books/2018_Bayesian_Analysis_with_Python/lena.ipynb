# %%
import scipy.misc
import matplotlib.pyplot as plt
lena=scipy.misc.face()
plt.imshow(lena)

# %%
def lena():
    import pickle
    import numpy as np
    f = open('./lena.dat','rb')
    lena = np.array(pickle.load(f))
    f.close()
    return lena
plt.imshow(lena())
